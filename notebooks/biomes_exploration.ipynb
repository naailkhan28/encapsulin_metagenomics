# %% [markdown]
# # Exploring MGnify Biomes Data
#
# We have biome information from MGnify for our encapsulin hits - let's analyze it!

# %%
import pandas as pd

biome_df = pd.read_csv("../biomes/processed_biome_dataframe.csv")
biome_df
# Out:
#                   MGYP   Biome Category  Biome Type     Biome Subtype  \
# 0     MGYP000000639651  Host-associated     Mammals  Digestive system
# 1     MGYP000001918706  Host-associated     Mammals  Digestive system
# 2     MGYP000002868012    Environmental     Aquatic       Aquaculture
# 3     MGYP000002868012    Environmental     Aquatic            Marine
# 4     MGYP000005098346       Engineered  Wastewater  Activated Sludge
# ...                ...              ...         ...               ...
# 1995  MGYP003976833229    Environmental     Aquatic            Marine
# 1996  MGYP003981698273    Environmental     Aquatic            Marine
# 1997  MGYP003996285317    Environmental     Aquatic            Marine
# 1998  MGYP003996594435    Environmental     Aquatic            Marine
# 1999  MGYP004105453633    Environmental     Aquatic            Marine
#
#        Ecosystem Type Specific Ecosystem
# 0     Large intestine              Fecal
# 1     Large intestine              Fecal
# ...
